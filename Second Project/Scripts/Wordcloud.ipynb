# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Wordcloud

# %% [markdown]
# #### clickbait wordcloud

# %%
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
text = open('clickbait_data.txt', 'r', encoding='utf-8').read()
wc = WordCloud(background_color = 'white', width = 1920, height = 1080)
wc.generate_from_text(text)
wc.to_file('word_cloud_clickbait.png')

# %% [markdown]
# #### non-clickbait wordcloud

# %%
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
text = open('non_clickbait_data.txt', 'r', encoding='utf-8').read()
wc = WordCloud(background_color = 'white', width = 1920, height = 1080)
wc.generate_from_text(text)
wc.to_file('word_cloud_non_clickbait.png')
